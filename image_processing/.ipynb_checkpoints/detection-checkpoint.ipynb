# %%
import cv2, os, math, glob
import matplotlib.pyplot as plt

from utils.common_tools import annotate_image, show_bgr
from utils.common_tools import stack_videos, assemble_frames_to_video
from utils.common_tools import find_nonzero_bounding_box, trim_video, draw_parallel_lines

from src.detection_routine import find_birds

# %%
def process_videos(base_name_list):
    for image_name in base_name_list:
        base_image_name = image_name

    # Paths for input and output
    truth_log_file_name = f"synth_videos/{base_image_name}/frame_data.txt"
    videos_to_process = [f"synth_videos/{base_image_name}/synth_track"]

    # Create the output directory for processed frames
    processed_frames_dir = f"synth_videos/{base_image_name}/processed_video_frames"
    rect_frames_dir = f"synth_videos/{base_image_name}/rectified_processed_video_frames"
    os.makedirs(processed_frames_dir, exist_ok=True)
    os.makedirs(rect_frames_dir, exist_ok=True)

    # Create or open the processed_data.txt file
    processed_data_file = open(f"synth_videos/{base_image_name}/processed_data.txt", "w")

    # Write the header for the processed_data.txt file
    processed_data_file.write("frame_index,cx,cy,w,h\n")

    for v in videos_to_process:
        video_to_process_path = v + "_video.mp4"
        cap = cv2.VideoCapture(video_to_process_path)

        if not cap.isOpened():
            raise ValueError(f"Error opening video file: {video_to_process_path}")

        for i in range(0, 61):
            if i % 10 == 0:
                print(f"processing frame {i} in {image_name}")
            frame_number = i
            # Set the frame position (0-based index)
            frame_index = frame_number - 1
            cap.set(cv2.CAP_PROP_POS_FRAMES, frame_index)

            # Read the frame
            ret, raw_frame = cap.read()
            if not ret:
                print(f"Frame {frame_index} could not be read.")
                continue

            raw_frame = raw_frame[0:720,0:1280]
            # Process the frame and get the output data
            rectified_frame, output_frame, cx, cy, w, h = find_birds(raw_frame,i)
            
            # Save the processed frame to the output directory
            output_frame_path = os.path.join(processed_frames_dir, f"frame_{frame_index:03}.jpg")
            rectified_frame_path = os.path.join(rect_frames_dir, f"frame_rect_{frame_index:03}.jpg")

            cv2.imwrite(output_frame_path, output_frame)
            cv2.imwrite(rectified_frame_path, rectified_frame)


            # Write the data for the current frame to processed_data.txt
            processed_data_file.write(f"{frame_index},{cx},{cy},{w},{h}\n")

    # Close the video capture and processed_data.txt file
    cap.release()
    processed_data_file.close()
    output_video_path = f"synth_videos/{base_image_name}/processed_track_video.mp4" 
    output_rect_video_path = f"synth_videos/{base_image_name}/rectified_processed_track_video.mp4" 

    assemble_frames_to_video(processed_frames_dir, output_video_path, fps=5, frame_pattern='frame_*.jpg')
    assemble_frames_to_video(rect_frames_dir, output_rect_video_path, fps=5, frame_pattern='frame_*.jpg')

    output_rectrim_video_path = f"synth_videos/{base_image_name}/processed_rect_trimmed_track_video.mp4"
    trim_video(output_rect_video_path , output_rectrim_video_path)

    stack_videos(video1_path = output_video_path,
                 video2_path = f"synth_videos/{base_image_name}/synth_track_box_video.mp4",
                 output_video_path = f"synth_videos/{base_image_name}/combined_video.mp4")
    
    stack_videos(video1_path = output_rect_video_path,
                 video2_path = f"synth_videos/{base_image_name}/synth_track_box_video.mp4",
                 output_video_path = f"synth_videos/{base_image_name}/rect_combined_video.mp4")

# %%
#image_list = #4","horizon_6"]
process_videos(["plane",])
# Out:
# processing frame 0 in plane
# Model found:  0.1274384676405 122.29936261165265
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.9919773070813742 0.12641606794860005
# perpendicular_direction: (18, -148)
# upside_down: False
# 122.29936261165265
# 720
# Region mask created.
# Model found:  0.1274384676405 122.29936261165265
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.9919773070813742 0.12641606794860005
# perpendicular_direction: (18, -148)
# upside_down: False
# 122.29936261165265
# 720
# Region mask created.
# Model found:  0.1269079062830763 122.93155999024737
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.9920431758640053 0.12589812239131457
# perpendicular_direction: (18, -148)
# upside_down: False
# 122.93155999024737
# 720
# Region mask created.
# Model found:  0.1269079062830763 122.93155999024737
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.9920431758640053 0.12589812239131457
# perpendicular_direction: (18, -148)
# upside_down: False
# 122.93155999024737
# 720
# Region mask created.
# Model found:  0.1269079062830763 122.93155999024737
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.9920431758640053 0.12589812239131457
# perpendicular_direction: (18, -148)
# upside_down: False
# 122.93155999024737
# 720
# Region mask created.
# Model found:  0.1269079062830763 122.93155999024737
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.9920431758640053 0.12589812239131457
# perpendicular_direction: (18, -148)
# upside_down: False
# 122.93155999024737
# 720
# Region mask created.
# Model found:  0.1269079062830763 122.93155999024737
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.9920431758640053 0.12589812239131457
# perpendicular_direction: (18, -148)
# upside_down: False
# 122.93155999024737
# 720
# Region mask created.
# Model found:  0.1269079062830763 122.93155999024737
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.9920431758640053 0.12589812239131457
# perpendicular_direction: (18, -148)
# upside_down: False
# 122.93155999024737
# 720
# Region mask created.
# Model found:  0.1269079062830763 122.93155999024737
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.9920431758640053 0.12589812239131457
# perpendicular_direction: (18, -148)
# upside_down: False
# 122.93155999024737
# 720
# Region mask created.
# Model found:  0.1269079062830763 122.93155999024737
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.9920431758640053 0.12589812239131457
# perpendicular_direction: (18, -148)
# upside_down: False
# 122.93155999024737
# 720
# Region mask created.
# processing frame 10 in plane
# Model found:  0.1269079062830763 122.93155999024737
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.9920431758640053 0.12589812239131457
# perpendicular_direction: (18, -148)
# upside_down: False
# 122.93155999024737
# 720
# Region mask created.
# Model found:  0.1269079062830763 122.93155999024737
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.9920431758640053 0.12589812239131457
# perpendicular_direction: (18, -148)
# upside_down: False
# 122.93155999024737
# 720
# Region mask created.
# Model found:  0.1269079062830763 122.93155999024737
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.9920431758640053 0.12589812239131457
# perpendicular_direction: (18, -148)
# upside_down: False
# 122.93155999024737
# 720
# Region mask created.
# Model found:  0.1269079062830763 122.93155999024737
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.9920431758640053 0.12589812239131457
# perpendicular_direction: (18, -148)
# upside_down: False
# 122.93155999024737
# 720
# Region mask created.
# Model found:  0.1269079062830763 122.93155999024737
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.9920431758640053 0.12589812239131457
# perpendicular_direction: (18, -148)
# upside_down: False
# 122.93155999024737
# 720
# Region mask created.
# Model found:  0.1269079062830763 122.93155999024737
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.9920431758640053 0.12589812239131457
# perpendicular_direction: (18, -148)
# upside_down: False
# 122.93155999024737
# 720
# Region mask created.
# Model found:  0.1269079062830763 122.93155999024737
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.9920431758640053 0.12589812239131457
# perpendicular_direction: (18, -148)
# upside_down: False
# 122.93155999024737
# 720
# Region mask created.
# Model found:  0.1269079062830763 122.93155999024737
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.9920431758640053 0.12589812239131457
# perpendicular_direction: (18, -148)
# upside_down: False
# 122.93155999024737
# 720
# Region mask created.
# Model found:  0.1269079062830763 122.93155999024737
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.9920431758640053 0.12589812239131457
# perpendicular_direction: (18, -148)
# upside_down: False
# 122.93155999024737
# 720
# Region mask created.
# Model found:  0.1269079062830763 122.93155999024737
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.9920431758640053 0.12589812239131457
# perpendicular_direction: (18, -148)
# upside_down: False
# 122.93155999024737
# 720
# Region mask created.
# processing frame 20 in plane
# Model found:  0.1269079062830763 122.93155999024737
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.9920431758640053 0.12589812239131457
# perpendicular_direction: (18, -148)
# upside_down: False
# 122.93155999024737
# 720
# Region mask created.
# Model found:  0.1269079062830763 122.93155999024737
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.9920431758640053 0.12589812239131457
# perpendicular_direction: (18, -148)
# upside_down: False
# 122.93155999024737
# 720
# Region mask created.
# Model found:  0.1269079062830763 122.93155999024737
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.9920431758640053 0.12589812239131457
# perpendicular_direction: (18, -148)
# upside_down: False
# 122.93155999024737
# 720
# Region mask created.
# Model found:  0.1269079062830763 122.93155999024737
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.9920431758640053 0.12589812239131457
# perpendicular_direction: (18, -148)
# upside_down: False
# 122.93155999024737
# 720
# Region mask created.
# Model found:  0.1269079062830763 122.93155999024737
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.9920431758640053 0.12589812239131457
# perpendicular_direction: (18, -148)
# upside_down: False
# 122.93155999024737
# 720
# Region mask created.
# Model found:  0.1269079062830763 122.93155999024737
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.9920431758640053 0.12589812239131457
# perpendicular_direction: (18, -148)
# upside_down: False
# 122.93155999024737
# 720
# Region mask created.
# Model found:  0.1269079062830763 122.93155999024737
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.9920431758640053 0.12589812239131457
# perpendicular_direction: (18, -148)
# upside_down: False
# 122.93155999024737
# 720
# Region mask created.
# Model found:  0.1269079062830763 122.93155999024737
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.9920431758640053 0.12589812239131457
# perpendicular_direction: (18, -148)
# upside_down: False
# 122.93155999024737
# 720
# Region mask created.
# Model found:  0.1269079062830763 122.93155999024737
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.9920431758640053 0.12589812239131457
# perpendicular_direction: (18, -148)
# upside_down: False
# 122.93155999024737
# 720
# Region mask created.
# Model found:  0.1269079062830763 122.93155999024737
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.9920431758640053 0.12589812239131457
# perpendicular_direction: (18, -148)
# upside_down: False
# 122.93155999024737
# 720
# Region mask created.
# processing frame 30 in plane
# Model found:  0.1269079062830763 122.93155999024737
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.9920431758640053 0.12589812239131457
# perpendicular_direction: (18, -148)
# upside_down: False
# 122.93155999024737
# 720
# Region mask created.
# Model found:  0.1269079062830763 122.93155999024737
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.9920431758640053 0.12589812239131457
# perpendicular_direction: (18, -148)
# upside_down: False
# 122.93155999024737
# 720
# Region mask created.
# Model found:  0.1269079062830763 122.93155999024737
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.9920431758640053 0.12589812239131457
# perpendicular_direction: (18, -148)
# upside_down: False
# 122.93155999024737
# 720
# Region mask created.
# Model found:  0.1269079062830763 122.93155999024737
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.9920431758640053 0.12589812239131457
# perpendicular_direction: (18, -148)
# upside_down: False
# 122.93155999024737
# 720
# Region mask created.
# Model found:  0.1269079062830763 122.93155999024737
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.9920431758640053 0.12589812239131457
# perpendicular_direction: (18, -148)
# upside_down: False
# 122.93155999024737
# 720
# Region mask created.
# Model found:  0.1269079062830763 122.93155999024737
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.9920431758640053 0.12589812239131457
# perpendicular_direction: (18, -148)
# upside_down: False
# 122.93155999024737
# 720
# Region mask created.
# Model found:  0.1269079062830763 122.93155999024737
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.9920431758640053 0.12589812239131457
# perpendicular_direction: (18, -148)
# upside_down: False
# 122.93155999024737
# 720
# Region mask created.
# Model found:  0.1269079062830763 122.93155999024737
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.9920431758640053 0.12589812239131457
# perpendicular_direction: (18, -148)
# upside_down: False
# 122.93155999024737
# 720
# Region mask created.
# Model found:  0.1269079062830763 122.93155999024737
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.9920431758640053 0.12589812239131457
# perpendicular_direction: (18, -148)
# upside_down: False
# 122.93155999024737
# 720
# Region mask created.
# Model found:  0.1269079062830763 122.93155999024737
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.9920431758640053 0.12589812239131457
# perpendicular_direction: (18, -148)
# upside_down: False
# 122.93155999024737
# 720
# Region mask created.
# processing frame 40 in plane
# Model found:  0.1269079062830763 122.93155999024737
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.9920431758640053 0.12589812239131457
# perpendicular_direction: (18, -148)
# upside_down: False
# 122.93155999024737
# 720
# Region mask created.
# Model found:  0.1269079062830763 122.93155999024737
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.9920431758640053 0.12589812239131457
# perpendicular_direction: (18, -148)
# upside_down: False
# 122.93155999024737
# 720
# Region mask created.
# Model found:  0.1269079062830763 122.93155999024737
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.9920431758640053 0.12589812239131457
# perpendicular_direction: (18, -148)
# upside_down: False
# 122.93155999024737
# 720
# Region mask created.
# Model found:  0.1269079062830763 122.93155999024737
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.9920431758640053 0.12589812239131457
# perpendicular_direction: (18, -148)
# upside_down: False
# 122.93155999024737
# 720
# Region mask created.
# Model found:  0.1269079062830763 122.93155999024737
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.9920431758640053 0.12589812239131457
# perpendicular_direction: (18, -148)
# upside_down: False
# 122.93155999024737
# 720
# Region mask created.
# Model found:  0.1269079062830763 122.93155999024737
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.9920431758640053 0.12589812239131457
# perpendicular_direction: (18, -148)
# upside_down: False
# 122.93155999024737
# 720
# Region mask created.
# Model found:  0.1269079062830763 122.93155999024737
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.9920431758640053 0.12589812239131457
# perpendicular_direction: (18, -148)
# upside_down: False
# 122.93155999024737
# 720
# Region mask created.
# Model found:  0.1269079062830763 122.93155999024737
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.9920431758640053 0.12589812239131457
# perpendicular_direction: (18, -148)
# upside_down: False
# 122.93155999024737
# 720
# Region mask created.
# Model found:  0.1269079062830763 122.93155999024737
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.9920431758640053 0.12589812239131457
# perpendicular_direction: (18, -148)
# upside_down: False
# 122.93155999024737
# 720
# Region mask created.
# Model found:  0.1269079062830763 122.93155999024737
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.9920431758640053 0.12589812239131457
# perpendicular_direction: (18, -148)
# upside_down: False
# 122.93155999024737
# 720
# Region mask created.
# processing frame 50 in plane
# Model found:  0.12320957021182102 124.29545573642235
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.992495040947619 0.12228488743251985
# perpendicular_direction: (18, -148)
# upside_down: False
# 124.29545573642235
# 720
# Region mask created.
# Model found:  0.12273383827681758 124.25338823555718
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.9925522401636647 0.12181974612554022
# perpendicular_direction: (18, -148)
# upside_down: False
# 124.25338823555718
# 720
# Region mask created.
# Model found:  0.12225617943522533 124.93533224940633
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.9926094583238068 0.12135264004593714
# perpendicular_direction: (18, -148)
# upside_down: False
# 124.93533224940633
# 720
# Region mask created.
# Model found:  0.1254972823695157 122.35719556111945
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.9922170301490324 0.1245205408044554
# perpendicular_direction: (18, -148)
# upside_down: False
# 122.35719556111945
# 720
# Region mask created.
# Model found:  0.12378054459159467 123.38395335423152
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.9924261113109786 0.12284304452499148
# perpendicular_direction: (18, -148)
# upside_down: False
# 123.38395335423152
# 720
# Region mask created.
# Model found:  0.1259538255745428 122.65526000967644
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.992160965557634 0.12496646919771619
# perpendicular_direction: (18, -148)
# upside_down: False
# 122.65526000967644
# 720
# Region mask created.
# Model found:  0.12436558680115214 123.97651095353467
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.992355167797916 0.12341483275834363
# perpendicular_direction: (18, -148)
# upside_down: False
# 123.97651095353467
# 720
# Region mask created.
# Model found:  0.12443746935408086 122.23951510765673
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.9923464291371942 0.12348507836439117
# perpendicular_direction: (18, -148)
# upside_down: False
# 122.23951510765673
# 720
# Region mask created.
# Model found:  0.1226671677805841 124.1979452125581
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.9925602393424311 0.12175455341175472
# perpendicular_direction: (18, -148)
# upside_down: False
# 124.1979452125581
# 720
# Region mask created.
# Model found:  0.12334841298006993 123.24853485580887
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.992478307462945 0.12242062414270016
# perpendicular_direction: (18, -148)
# upside_down: False
# 123.24853485580887
# 720
# Region mask created.
# processing frame 60 in plane
# Model found:  0.12261974475548648 123.98027958241018
# Blue sky ratio: 0.0
# Red sky ratio: 1.0
# Red line selected.
# 0.9925659266666856 0.1217081805808619
# perpendicular_direction: (18, -148)
# upside_down: False
# 123.98027958241018
# 720
# Region mask created.
# Starting video assembly from 61 frames...
# Processed 10/61 frames.
# Processed 20/61 frames.
# Processed 30/61 frames.
# Processed 40/61 frames.
# Processed 50/61 frames.
# Processed 60/61 frames.
# Processed 61/61 frames.
# Video successfully saved to 'synth_videos/plane/processed_track_video.mp4'.
# Starting video assembly from 61 frames...
# Processed 10/61 frames.
# Processed 20/61 frames.
# Processed 30/61 frames.
# Processed 40/61 frames.
# Processed 50/61 frames.
# Processed 60/61 frames.
# Processed 61/61 frames.
# Video successfully saved to 'synth_videos/plane/rectified_processed_track_video.mp4'.
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_505060/2368455317.py in <module>
#       1 #image_list = #4","horizon_6"]
# ----> 2 process_videos(["plane",])
#
# /tmp/ipykernel_505060/2975620098.py in process_videos(base_name_list)
#      67     trim_video(output_rect_video_path , output_rectrim_video_path)
#      68
# ---> 69     stack_videos(video1_path = output_video_path,
#      70                  video2_path = f"synth_videos/{base_image_name}/synth_track_box_video.mp4",
#      71                  output_video_path = f"synth_videos/{base_image_name}/combined_video.mp4")
#
# ~/mlearning/image_processing/utils/common_tools.py in stack_videos(video1_path, video2_path, output_video_path)
#     210     # Calculate aspect ratios and determine new heights
#     211     new_height1 = int(height1 * (new_width / width1))
# --> 212     new_height2 = int(height2 * (new_width / width2))
#     213
#     214     # Output video dimensions
#
# ZeroDivisionError: division by zero
