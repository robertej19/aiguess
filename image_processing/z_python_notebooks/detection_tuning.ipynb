# %%
import cv2,sys,os
import matplotlib.pyplot as plt

parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.append(parent_dir)

from utils.detection_tools import detect_sky, estimate_horizon_line_by_edges
from utils.detection_tools import  downsampler, rotate_and_center_horizon
from utils.common_tools import annotate_image, show_bgr, draw_parallel_lines
from src.detection_routine import detect_objects

# %%
base_image_name = "horizon_2"
cap = cv2.VideoCapture(parent_dir+f"/synth_videos/{base_image_name}/synth_track_video.mp4")

# Set the frame position (0-based index)
frame_index = 55
cap.set(cv2.CAP_PROP_POS_FRAMES, frame_index)

# Read the frame
ret, raw_frame = cap.read()

# %%
rectified_frame, complete_frame, x,y,w,h = detect_objects(raw_frame,1,debug=True)
# Out:
# Warning: No ImageProcessingParams object was passed. Using default values.
# HSV Values
# {'min_h': 108, 'max_h': 164, 'min_s': 58, 'max_s': 146, 'min_v': 155, 'max_v': 241}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_439464/221751002.py in <module>
# ----> 1 rectified_frame, complete_frame, x,y,w,h = detect_objects(raw_frame,1,debug=True)
#
# ValueError: too many values to unpack (expected 6)
